# %%
import tornado

import motorengine
from gargantua.models.users import Users


io_loop = tornado.ioloop.IOLoop.instance()
motorengine.connect("test", host="blog.laisky.com", port=27017, io_loop=io_loop)

# %%
user = Users.objects.create(account='laisky@gmail.com', password='1dsdas23')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-a98aab687600> in <module>()
# ----> 1 user = Users.objects.create(account='laisky@gmail.com', password='1dsdas23')
#
# /Users/laisky/repo/laisky-blog/venv/lib/python3.4/site-packages/tornado/concurrent.py in wrapper(*args, **kwargs)
#     290             # go ahead and raise it to the caller directly without waiting
#     291             # for them to inspect the Future.
# --> 292             raise_exc_info(exc_info)
#     293
#     294         # If the caller passed in a callback, schedule it to be called
#
# /Users/laisky/repo/laisky-blog/venv/lib/python3.4/site-packages/tornado/util.py in raise_exc_info(exc_info)
#
# /Users/laisky/repo/laisky-blog/venv/lib/python3.4/site-packages/tornado/concurrent.py in wrapper(*args, **kwargs)
#     278         with ExceptionStackContext(handle_error):
# ...

# %%
user.save()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-79b22bfa6db2> in <module>()
# ----> 1 user.save()
#
# /Users/laisky/repo/laisky-blog/venv/lib/python3.4/site-packages/tornado/concurrent.py in wrapper(*args, **kwargs)
#     290             # go ahead and raise it to the caller directly without waiting
#     291             # for them to inspect the Future.
# --> 292             raise_exc_info(exc_info)
#     293
#     294         # If the caller passed in a callback, schedule it to be called
#
# /Users/laisky/repo/laisky-blog/venv/lib/python3.4/site-packages/tornado/util.py in raise_exc_info(exc_info)
#
# /Users/laisky/repo/laisky-blog/venv/lib/python3.4/site-packages/tornado/concurrent.py in wrapper(*args, **kwargs)
#     278         with ExceptionStackContext(handle_error):
#     279             try:
# --> 280                 result = f(*args, **kwargs)
# ...
